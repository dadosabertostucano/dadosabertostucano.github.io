# %%
#Importando biblioteca para trabalhar
import pandas as pd
import numpy as np 

mes = 'out'
df_mes = pd.read_csv(mes + '.csv', encoding='latin-1', decimal=',')
#df_mes = df_mes.drop(['Unnamed: 7'], axis=1)
df_mes.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-66-4689c7866a97> in <module>
#       4
#       5 mes = 'out'
# ----> 6 df_mes = pd.read_csv(mes + '.csv', encoding='latin-1', decimal=',')
#       7 #df_mes = df_mes.drop(['Unnamed: 7'], axis=1)
#       8 df_mes.head()
#
# c:\users\micro\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# c:\users\micro\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(filepath_or_buffer, **kwds)
#     458
#     459     if chunksize or iterator:
#
# c:\users\micro\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     812             self.options["has_index_names"] = kwds["has_index_names"]
#     813
# --> 814         self._engine = self._make_engine(self.engine)
#     815
#     816     def close(self):
#
# c:\users\micro\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1043             )
#    1044         # error: Too many arguments for "ParserBase"
# -> 1045         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1046
#    1047     def _failover_to_python(self):
#
# c:\users\micro\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1860
#    1861         # open handles
# -> 1862         self._open_handles(src, kwds)
#    1863         assert self.handles is not None
#    1864         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# c:\users\micro\appdata\local\programs\python\python38\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1355         Let the readers open IOHanldes after they are done with their potential raises.
#    1356         """
# -> 1357         self.handles = get_handle(
#    1358             src,
#    1359             "r",
#
# c:\users\micro\appdata\local\programs\python\python38\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'out.csv'

# %%
df_mes['Salário Base'] = df_mes['Salário Base'].apply(lambda x: x.split('R$')[1])
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].apply(lambda x: x.split('R$')[1])
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].apply(lambda x: x.split('R$')[1])

df_mes['Salário Base'] = df_mes['Salário Base'].apply(lambda x: x.split()[0].replace('.', ''))
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].apply(lambda x: x.split()[0].replace('.', ''))
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].apply(lambda x: x.split()[0].replace('.', ''))

df_mes['Salário Base'] = df_mes['Salário Base'].str.replace(',', '.').astype(float)
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].str.replace(',', '.').astype(float)
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].str.replace(',', '.').astype(float)

lista_colunas_sum = ['Salário Base', 'Salário Vantagens', 'Salário Gratificação']
df_mes['Valor Recebido'] = df_mes.loc[:,lista_colunas_sum].sum(axis=1)
df_mes.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0              ABEL MACEDO DE JESUS        157  Cargo Efetivo/ Estatutário
# 1      ADEMILTON SANTANA DE MIRANDA        156          Cargo Comissionado
# 2            AFRÂNIO FARIAS BATISTA        142          Cargo Comissionado
# 3    ALFREDO JORGE COSTA DE FREITAS        115          Cargo Comissionado
# 4  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
#
#                  Cargo  Salário Base  Salário Vantagens  Salário Gratificação  \
# 0  AGENTE DE SEGURANÇA         724.0             144.80                   0.0
# 1             Contador        7000.0               0.00                   0.0
# 2  CHEFE DE TRANSPORTE        1200.0             800.00                   0.0
# 3           TESOUREIRO        1700.0             800.00                   0.0
# 4        RECEPCIONISTA         724.0             241.33                   0.0
#
#    Valor Recebido
# 0          868.80
# 1         7000.00
# 2         2000.00
# 3         2500.00
# 4          965.33

# %%
df_mes.insert(loc=3, 
             column = 'Mês',
             value = 'setembro')

df_mes.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0              ABEL MACEDO DE JESUS        157  Cargo Efetivo/ Estatutário
# 1      ADEMILTON SANTANA DE MIRANDA        156          Cargo Comissionado
# 2            AFRÂNIO FARIAS BATISTA        142          Cargo Comissionado
# 3    ALFREDO JORGE COSTA DE FREITAS        115          Cargo Comissionado
# 4  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
#
#         Mês                Cargo  Salário Base  Salário Vantagens  \
# 0  setembro  AGENTE DE SEGURANÇA         724.0             144.80
# 1  setembro             Contador        7000.0               0.00
# 2  setembro  CHEFE DE TRANSPORTE        1200.0             800.00
# 3  setembro           TESOUREIRO        1700.0             800.00
# 4  setembro        RECEPCIONISTA         724.0             241.33
#
#    Salário Gratificação  Valor Recebido
# 0                   0.0          868.80
# 1                   0.0         7000.00
# 2                   0.0         2000.00
# 3                   0.0         2500.00
# 4                   0.0          965.33

# %%
df_mes.insert(loc=4, 
             column = 'Ano',
             value = '2014')

df_mes.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0              ABEL MACEDO DE JESUS        157  Cargo Efetivo/ Estatutário
# 1      ADEMILTON SANTANA DE MIRANDA        156          Cargo Comissionado
# 2            AFRÂNIO FARIAS BATISTA        142          Cargo Comissionado
# 3    ALFREDO JORGE COSTA DE FREITAS        115          Cargo Comissionado
# 4  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
#
#         Mês   Ano                Cargo  Salário Base  Salário Vantagens  \
# 0  setembro  2014  AGENTE DE SEGURANÇA         724.0             144.80
# 1  setembro  2014             Contador        7000.0               0.00
# 2  setembro  2014  CHEFE DE TRANSPORTE        1200.0             800.00
# 3  setembro  2014           TESOUREIRO        1700.0             800.00
# 4  setembro  2014        RECEPCIONISTA         724.0             241.33
#
#    Salário Gratificação  Valor Recebido
# 0                   0.0          868.80
# 1                   0.0         7000.00
# 2                   0.0         2000.00
# 3                   0.0         2500.00
# 4                   0.0          965.33

# %%
df_mes.to_csv('dados-limpos/' + mes + '-2014-limpo.csv', index=False, encoding='utf-8')

# %%
df = pd.read_csv('dados-limpos/' + mes + '-2014-limpo.csv')
df.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0              ABEL MACEDO DE JESUS        157  Cargo Efetivo/ Estatutário
# 1      ADEMILTON SANTANA DE MIRANDA        156          Cargo Comissionado
# 2            AFRÂNIO FARIAS BATISTA        142          Cargo Comissionado
# 3    ALFREDO JORGE COSTA DE FREITAS        115          Cargo Comissionado
# 4  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
#
#         Mês   Ano                Cargo  Salário Base  Salário Vantagens  \
# 0  setembro  2014  AGENTE DE SEGURANÇA         724.0             144.80
# 1  setembro  2014             Contador        7000.0               0.00
# 2  setembro  2014  CHEFE DE TRANSPORTE        1200.0             800.00
# 3  setembro  2014           TESOUREIRO        1700.0             800.00
# 4  setembro  2014        RECEPCIONISTA         724.0             241.33
#
#    Salário Gratificação  Valor Recebido
# 0                   0.0          868.80
# 1                   0.0         7000.00
# 2                   0.0         2000.00
# 3                   0.0         2500.00
# 4                   0.0          965.33

# %%
import openpyxl
df = pd.read_csv('dados-limpos/' + mes + '-2014-limpo.csv')
df.to_excel('dados-limpos/xlsx/' + mes + '-2014-xlsx.xlsx', index=False, encoding='utf-8')
