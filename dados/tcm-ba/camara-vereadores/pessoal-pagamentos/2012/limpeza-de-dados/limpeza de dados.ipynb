# %%
#Importando biblioteca para trabalhar
import pandas as pd
import numpy as np 

mes = 'dez'
df_mes = pd.read_csv(mes + '.csv', encoding='latin-1', decimal=',')
#df_mes = df_mes.drop(['Unnamed: 7'], axis=1)
df_mes.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0            AFRÂNIO FARIAS BATISTA        142          Cargo Comissionado
# 1    ALFREDO JORGE COSTA DE FREITAS        115          Cargo Comissionado
# 2          ANA GABRIELA SILVA COSTA        121      Trabalhador Temporário
# 3  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 4         BELMIRO FERREIRA DA SILVA          1             Agente Político
#
#                  Cargo Salário Base Salário Vantagens Salário Gratificação
# 0  CHEFE DE TRANSPORTE  R$ 1.200,00         R$ 500,00              R$ 0,00
# 1           TESOUREIRO  R$ 1.700,00         R$ 800,00              R$ 0,00
# 2             ASSESSOR    R$ 622,73           R$ 0,00              R$ 0,00
# 3        RECEPCIONISTA    R$ 622,73           R$ 0,00              R$ 0,00
# 4             VEREADOR  R$ 3.715,20           R$ 0,00              R$ 0,00

# %%
df_mes['Salário Base'] = df_mes['Salário Base'].apply(lambda x: x.split('R$')[1])
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].apply(lambda x: x.split('R$')[1])
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].apply(lambda x: x.split('R$')[1])

df_mes['Salário Base'] = df_mes['Salário Base'].apply(lambda x: x.split()[0].replace('.', ''))
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].apply(lambda x: x.split()[0].replace('.', ''))
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].apply(lambda x: x.split()[0].replace('.', ''))

df_mes['Salário Base'] = df_mes['Salário Base'].str.replace(',', '.').astype(float)
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].str.replace(',', '.').astype(float)
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].str.replace(',', '.').astype(float)

lista_colunas_sum = ['Salário Base', 'Salário Vantagens', 'Salário Gratificação']
df_mes['Valor Recebido'] = df_mes.loc[:,lista_colunas_sum].sum(axis=1)
df_mes.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0            AFRÂNIO FARIAS BATISTA        142          Cargo Comissionado
# 1    ALFREDO JORGE COSTA DE FREITAS        115          Cargo Comissionado
# 2          ANA GABRIELA SILVA COSTA        121      Trabalhador Temporário
# 3  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 4         BELMIRO FERREIRA DA SILVA          1             Agente Político
#
#                  Cargo  Salário Base  Salário Vantagens  Salário Gratificação  \
# 0  CHEFE DE TRANSPORTE       1200.00              500.0                   0.0
# 1           TESOUREIRO       1700.00              800.0                   0.0
# 2             ASSESSOR        622.73                0.0                   0.0
# 3        RECEPCIONISTA        622.73                0.0                   0.0
# 4             VEREADOR       3715.20                0.0                   0.0
#
#    Valor Recebido
# 0         1700.00
# 1         2500.00
# 2          622.73
# 3          622.73
# 4         3715.20

# %%
df_mes.insert(loc=3, 
             column = 'Mês',
             value = 'dezembro')

df_mes.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0            AFRÂNIO FARIAS BATISTA        142          Cargo Comissionado
# 1    ALFREDO JORGE COSTA DE FREITAS        115          Cargo Comissionado
# 2          ANA GABRIELA SILVA COSTA        121      Trabalhador Temporário
# 3  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 4         BELMIRO FERREIRA DA SILVA          1             Agente Político
#
#         Mês                Cargo  Salário Base  Salário Vantagens  \
# 0  dezembro  CHEFE DE TRANSPORTE       1200.00              500.0
# 1  dezembro           TESOUREIRO       1700.00              800.0
# 2  dezembro             ASSESSOR        622.73                0.0
# 3  dezembro        RECEPCIONISTA        622.73                0.0
# 4  dezembro             VEREADOR       3715.20                0.0
#
#    Salário Gratificação  Valor Recebido
# 0                   0.0         1700.00
# 1                   0.0         2500.00
# 2                   0.0          622.73
# 3                   0.0          622.73
# 4                   0.0         3715.20

# %%
df_mes.insert(loc=4, 
             column = 'Ano',
             value = '2012')

df_mes.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0            AFRÂNIO FARIAS BATISTA        142          Cargo Comissionado
# 1    ALFREDO JORGE COSTA DE FREITAS        115          Cargo Comissionado
# 2          ANA GABRIELA SILVA COSTA        121      Trabalhador Temporário
# 3  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 4         BELMIRO FERREIRA DA SILVA          1             Agente Político
#
#         Mês   Ano                Cargo  Salário Base  Salário Vantagens  \
# 0  dezembro  2012  CHEFE DE TRANSPORTE       1200.00              500.0
# 1  dezembro  2012           TESOUREIRO       1700.00              800.0
# 2  dezembro  2012             ASSESSOR        622.73                0.0
# 3  dezembro  2012        RECEPCIONISTA        622.73                0.0
# 4  dezembro  2012             VEREADOR       3715.20                0.0
#
#    Salário Gratificação  Valor Recebido
# 0                   0.0         1700.00
# 1                   0.0         2500.00
# 2                   0.0          622.73
# 3                   0.0          622.73
# 4                   0.0         3715.20

# %%
df_mes.to_csv('dados-limpos/' + mes + '-2012-limpo.csv', index=False, encoding='utf-8')

# %%
df = pd.read_csv('dados-limpos/' + mes + '-2012-limpo.csv')
df.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0            AFRÂNIO FARIAS BATISTA        142          Cargo Comissionado
# 1    ALFREDO JORGE COSTA DE FREITAS        115          Cargo Comissionado
# 2          ANA GABRIELA SILVA COSTA        121      Trabalhador Temporário
# 3  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 4         BELMIRO FERREIRA DA SILVA          1             Agente Político
#
#         Mês   Ano                Cargo  Salário Base  Salário Vantagens  \
# 0  dezembro  2012  CHEFE DE TRANSPORTE       1200.00              500.0
# 1  dezembro  2012           TESOUREIRO       1700.00              800.0
# 2  dezembro  2012             ASSESSOR        622.73                0.0
# 3  dezembro  2012        RECEPCIONISTA        622.73                0.0
# 4  dezembro  2012             VEREADOR       3715.20                0.0
#
#    Salário Gratificação  Valor Recebido
# 0                   0.0         1700.00
# 1                   0.0         2500.00
# 2                   0.0          622.73
# 3                   0.0          622.73
# 4                   0.0         3715.20

# %%
import openpyxl
df = pd.read_csv('dados-limpos/' + mes + '-2012-limpo.csv')
df.to_excel('dados-limpos/xlsx/' + mes + '-2012-xlsx.xlsx', index=False, encoding='utf-8')
