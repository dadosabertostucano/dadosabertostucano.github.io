# %%
#Importando biblioteca para trabalhar
import pandas as pd
import numpy as np 

mes = 'dez'
df_mes = pd.read_csv(mes + '.csv', encoding='latin-1', decimal=',')
#df_mes = df_mes.drop(['Unnamed: 7'], axis=1)
df_mes.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0    ALFREDO JORGE COSTA DE FREITAS        115          Cargo Comissionado
# 1          ANA GABRIELA SILVA COSTA        121      Trabalhador Temporário
# 2  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 3  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 4          ARGEMIRA SANTOS DE JESUS         54  Cargo Efetivo/ Estatutário
#
#                     Cargo Salário Base Salário Vantagens Salário Gratificação
# 0              TESOUREIRO  R$ 1.700,00           R$ 0,00              R$ 0,00
# 1                ASSESSOR    R$ 545,00           R$ 0,00              R$ 0,00
# 2           RECEPCIONISTA    R$ 545,00           R$ 0,00              R$ 0,00
# 3           RECEPCIONISTA      R$ 0,00           R$ 0,00              R$ 0,00
# 4  APOSENTADO/PENSIONISTA    R$ 620,40         R$ 395,01              R$ 0,00

# %%
df_mes['Salário Base'] = df_mes['Salário Base'].apply(lambda x: x.split('R$')[1])
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].apply(lambda x: x.split('R$')[1])
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].apply(lambda x: x.split('R$')[1])

df_mes['Salário Base'] = df_mes['Salário Base'].apply(lambda x: x.split()[0].replace('.', ''))
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].apply(lambda x: x.split()[0].replace('.', ''))
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].apply(lambda x: x.split()[0].replace('.', ''))

df_mes['Salário Base'] = df_mes['Salário Base'].str.replace(',', '.').astype(float)
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].str.replace(',', '.').astype(float)
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].str.replace(',', '.').astype(float)

lista_colunas_sum = ['Salário Base', 'Salário Vantagens', 'Salário Gratificação']
df_mes['Valor Recebido'] = df_mes.loc[:,lista_colunas_sum].sum(axis=1)
df_mes.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0    ALFREDO JORGE COSTA DE FREITAS        115          Cargo Comissionado
# 1          ANA GABRIELA SILVA COSTA        121      Trabalhador Temporário
# 2  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 3  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 4          ARGEMIRA SANTOS DE JESUS         54  Cargo Efetivo/ Estatutário
#
#                     Cargo  Salário Base  Salário Vantagens  \
# 0              TESOUREIRO        1700.0               0.00
# 1                ASSESSOR         545.0               0.00
# 2           RECEPCIONISTA         545.0               0.00
# 3           RECEPCIONISTA           0.0               0.00
# 4  APOSENTADO/PENSIONISTA         620.4             395.01
#
#    Salário Gratificação  Valor Recebido
# 0                   0.0         1700.00
# 1                   0.0          545.00
# 2                   0.0          545.00
# 3                   0.0            0.00
# 4                   0.0         1015.41

# %%
df_mes.insert(loc=3, 
             column = 'Mês',
             value = 'dezembro')

df_mes.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0    ALFREDO JORGE COSTA DE FREITAS        115          Cargo Comissionado
# 1          ANA GABRIELA SILVA COSTA        121      Trabalhador Temporário
# 2  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 3  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 4          ARGEMIRA SANTOS DE JESUS         54  Cargo Efetivo/ Estatutário
#
#         Mês                   Cargo  Salário Base  Salário Vantagens  \
# 0  dezembro              TESOUREIRO        1700.0               0.00
# 1  dezembro                ASSESSOR         545.0               0.00
# 2  dezembro           RECEPCIONISTA         545.0               0.00
# 3  dezembro           RECEPCIONISTA           0.0               0.00
# 4  dezembro  APOSENTADO/PENSIONISTA         620.4             395.01
#
#    Salário Gratificação  Valor Recebido
# 0                   0.0         1700.00
# 1                   0.0          545.00
# 2                   0.0          545.00
# 3                   0.0            0.00
# 4                   0.0         1015.41

# %%
df_mes.insert(loc=4, 
             column = 'Ano',
             value = '2011')

df_mes.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0    ALFREDO JORGE COSTA DE FREITAS        115          Cargo Comissionado
# 1          ANA GABRIELA SILVA COSTA        121      Trabalhador Temporário
# 2  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 3  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 4          ARGEMIRA SANTOS DE JESUS         54  Cargo Efetivo/ Estatutário
#
#         Mês   Ano                   Cargo  Salário Base  Salário Vantagens  \
# 0  dezembro  2011              TESOUREIRO        1700.0               0.00
# 1  dezembro  2011                ASSESSOR         545.0               0.00
# 2  dezembro  2011           RECEPCIONISTA         545.0               0.00
# 3  dezembro  2011           RECEPCIONISTA           0.0               0.00
# 4  dezembro  2011  APOSENTADO/PENSIONISTA         620.4             395.01
#
#    Salário Gratificação  Valor Recebido
# 0                   0.0         1700.00
# 1                   0.0          545.00
# 2                   0.0          545.00
# 3                   0.0            0.00
# 4                   0.0         1015.41

# %%
df_mes.to_csv('dados-limpos/' + mes + '-2011-limpo.csv', index=False, encoding='utf-8')

# %%
df = pd.read_csv('dados-limpos/' + mes + '-2011-limpo.csv')
df.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0    ALFREDO JORGE COSTA DE FREITAS        115          Cargo Comissionado
# 1          ANA GABRIELA SILVA COSTA        121      Trabalhador Temporário
# 2  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 3  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 4          ARGEMIRA SANTOS DE JESUS         54  Cargo Efetivo/ Estatutário
#
#         Mês   Ano                   Cargo  Salário Base  Salário Vantagens  \
# 0  dezembro  2011              TESOUREIRO        1700.0               0.00
# 1  dezembro  2011                ASSESSOR         545.0               0.00
# 2  dezembro  2011           RECEPCIONISTA         545.0               0.00
# 3  dezembro  2011           RECEPCIONISTA           0.0               0.00
# 4  dezembro  2011  APOSENTADO/PENSIONISTA         620.4             395.01
#
#    Salário Gratificação  Valor Recebido
# 0                   0.0         1700.00
# 1                   0.0          545.00
# 2                   0.0          545.00
# 3                   0.0            0.00
# 4                   0.0         1015.41

# %%
import openpyxl
df = pd.read_csv('dados-limpos/' + mes + '-2011-limpo.csv')
df.to_excel('dados-limpos/xlsx/' + mes + '-2011-xlsx.xlsx', index=False, encoding='utf-8')
