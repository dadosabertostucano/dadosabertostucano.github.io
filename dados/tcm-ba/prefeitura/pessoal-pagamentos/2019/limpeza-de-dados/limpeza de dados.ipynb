# %%
#Importando biblioteca para trabalhar
import pandas as pd
import numpy as np 

mes = 'dez'
df_mes = pd.read_csv(mes + '.csv', encoding='latin-1', decimal=',')
#df_mes = df_mes.drop(['Unnamed: 7'], axis=1)
df_mes.head()
# Out:
#                           Nome  Matrícula               Tipo Servidor  \
# 0         ABIGAIL DONATA ALVES       1951  Cargo Efetivo/ Estatutário
# 1         ABIGAIL DONATA ALVES       1951  Cargo Efetivo/ Estatutário
# 2  ABIGAIL OLIVEIRA DOS SANTOS       9929  Cargo Efetivo/ Estatutário
# 3  ABIGAIL OLIVEIRA DOS SANTOS       9929  Cargo Efetivo/ Estatutário
# 4           ABRAHAO SILVA MAIA       8063  Cargo Efetivo/ Estatutário
#
#                          Cargo Salário Base Salário Vantagens  \
# 0  AGENTE COMUNITÁRIO DE SAÚDE  R$ 1.250,00         R$ 375,00
# 1  AGENTE COMUNITÁRIO DE SAÚDE      R$ 0,00           R$ 0,00
# 2            AGENTE DE LIMPEZA    R$ 998,00          R$ 49,90
# 3            AGENTE DE LIMPEZA      R$ 0,00           R$ 0,00
# 4             GUARDA MUNICIPAL  R$ 1.128,75         R$ 338,63
#
#   Salário Gratificação
# 0              R$ 0,00
# 1              R$ 0,00
# 2              R$ 0,00
# 3              R$ 0,00
# 4            R$ 620,81

# %%
df_mes['Salário Base'] = df_mes['Salário Base'].apply(lambda x: x.split('R$')[1])
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].apply(lambda x: x.split('R$')[1])
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].apply(lambda x: x.split('R$')[1])

df_mes['Salário Base'] = df_mes['Salário Base'].apply(lambda x: x.split()[0].replace('.', ''))
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].apply(lambda x: x.split()[0].replace('.', ''))
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].apply(lambda x: x.split()[0].replace('.', ''))

df_mes['Salário Base'] = df_mes['Salário Base'].str.replace(',', '.').astype(float)
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].str.replace(',', '.').astype(float)
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].str.replace(',', '.').astype(float)

lista_colunas_sum = ['Salário Base', 'Salário Vantagens', 'Salário Gratificação']
df_mes['Valor Recebido'] = df_mes.loc[:,lista_colunas_sum].sum(axis=1)
df_mes.head()
# Out:
#                           Nome  Matrícula               Tipo Servidor  \
# 0         ABIGAIL DONATA ALVES       1951  Cargo Efetivo/ Estatutário
# 1         ABIGAIL DONATA ALVES       1951  Cargo Efetivo/ Estatutário
# 2  ABIGAIL OLIVEIRA DOS SANTOS       9929  Cargo Efetivo/ Estatutário
# 3  ABIGAIL OLIVEIRA DOS SANTOS       9929  Cargo Efetivo/ Estatutário
# 4           ABRAHAO SILVA MAIA       8063  Cargo Efetivo/ Estatutário
#
#                          Cargo  Salário Base  Salário Vantagens  \
# 0  AGENTE COMUNITÁRIO DE SAÚDE       1250.00             375.00
# 1  AGENTE COMUNITÁRIO DE SAÚDE          0.00               0.00
# 2            AGENTE DE LIMPEZA        998.00              49.90
# 3            AGENTE DE LIMPEZA          0.00               0.00
# 4             GUARDA MUNICIPAL       1128.75             338.63
#
#    Salário Gratificação  Valor Recebido
# 0                  0.00         1625.00
# 1                  0.00            0.00
# 2                  0.00         1047.90
# 3                  0.00            0.00
# 4                620.81         2088.19

# %%
df_mes.insert(loc=3, 
             column = 'Mês',
             value = 'dezembro')

df_mes.head()
# Out:
#                           Nome  Matrícula               Tipo Servidor  \
# 0         ABIGAIL DONATA ALVES       1951  Cargo Efetivo/ Estatutário
# 1         ABIGAIL DONATA ALVES       1951  Cargo Efetivo/ Estatutário
# 2  ABIGAIL OLIVEIRA DOS SANTOS       9929  Cargo Efetivo/ Estatutário
# 3  ABIGAIL OLIVEIRA DOS SANTOS       9929  Cargo Efetivo/ Estatutário
# 4           ABRAHAO SILVA MAIA       8063  Cargo Efetivo/ Estatutário
#
#         Mês                        Cargo  Salário Base  Salário Vantagens  \
# 0  dezembro  AGENTE COMUNITÁRIO DE SAÚDE       1250.00             375.00
# 1  dezembro  AGENTE COMUNITÁRIO DE SAÚDE          0.00               0.00
# 2  dezembro            AGENTE DE LIMPEZA        998.00              49.90
# 3  dezembro            AGENTE DE LIMPEZA          0.00               0.00
# 4  dezembro             GUARDA MUNICIPAL       1128.75             338.63
#
#    Salário Gratificação  Valor Recebido
# 0                  0.00         1625.00
# 1                  0.00            0.00
# 2                  0.00         1047.90
# 3                  0.00            0.00
# 4                620.81         2088.19

# %%
df_mes.insert(loc=4, 
             column = 'Ano',
             value = '2019')

df_mes.head()
# Out:
#                           Nome  Matrícula               Tipo Servidor  \
# 0         ABIGAIL DONATA ALVES       1951  Cargo Efetivo/ Estatutário
# 1         ABIGAIL DONATA ALVES       1951  Cargo Efetivo/ Estatutário
# 2  ABIGAIL OLIVEIRA DOS SANTOS       9929  Cargo Efetivo/ Estatutário
# 3  ABIGAIL OLIVEIRA DOS SANTOS       9929  Cargo Efetivo/ Estatutário
# 4           ABRAHAO SILVA MAIA       8063  Cargo Efetivo/ Estatutário
#
#         Mês   Ano                        Cargo  Salário Base  \
# 0  dezembro  2019  AGENTE COMUNITÁRIO DE SAÚDE       1250.00
# 1  dezembro  2019  AGENTE COMUNITÁRIO DE SAÚDE          0.00
# 2  dezembro  2019            AGENTE DE LIMPEZA        998.00
# 3  dezembro  2019            AGENTE DE LIMPEZA          0.00
# 4  dezembro  2019             GUARDA MUNICIPAL       1128.75
#
#    Salário Vantagens  Salário Gratificação  Valor Recebido
# 0             375.00                  0.00         1625.00
# 1               0.00                  0.00            0.00
# 2              49.90                  0.00         1047.90
# 3               0.00                  0.00            0.00
# 4             338.63                620.81         2088.19

# %%
df_mes.to_csv('dados-limpos/' + mes + '-2019-limpo.csv', index=False, encoding='utf-8')

# %%
df = pd.read_csv('dados-limpos/' + mes + '-2019-limpo.csv')
df.head()
# Out:
#                           Nome  Matrícula               Tipo Servidor  \
# 0         ABIGAIL DONATA ALVES       1951  Cargo Efetivo/ Estatutário
# 1         ABIGAIL DONATA ALVES       1951  Cargo Efetivo/ Estatutário
# 2  ABIGAIL OLIVEIRA DOS SANTOS       9929  Cargo Efetivo/ Estatutário
# 3  ABIGAIL OLIVEIRA DOS SANTOS       9929  Cargo Efetivo/ Estatutário
# 4           ABRAHAO SILVA MAIA       8063  Cargo Efetivo/ Estatutário
#
#         Mês   Ano                        Cargo  Salário Base  \
# 0  dezembro  2019  AGENTE COMUNITÁRIO DE SAÚDE       1250.00
# 1  dezembro  2019  AGENTE COMUNITÁRIO DE SAÚDE          0.00
# 2  dezembro  2019            AGENTE DE LIMPEZA        998.00
# 3  dezembro  2019            AGENTE DE LIMPEZA          0.00
# 4  dezembro  2019             GUARDA MUNICIPAL       1128.75
#
#    Salário Vantagens  Salário Gratificação  Valor Recebido
# 0             375.00                  0.00         1625.00
# 1               0.00                  0.00            0.00
# 2              49.90                  0.00         1047.90
# 3               0.00                  0.00            0.00
# 4             338.63                620.81         2088.19

# %%
import openpyxl
df = pd.read_csv('dados-limpos/' + mes + '-2019-limpo.csv')
df.to_excel('dados-limpos/xlsx/' + mes + '-2019-xlsx.xlsx', index=False, encoding='utf-8')
