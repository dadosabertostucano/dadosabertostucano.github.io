# %%
#Importando biblioteca para trabalhar
import pandas as pd
import numpy as np 

mes = 'mar'
df_mes = pd.read_csv(mes + '-2017.csv', encoding='latin-1', decimal=',')
#df_mes = df_mes.drop(['Unnamed: 7'], axis=1)
df_mes.head()
# Out:
#                           Nome  Matrícula               Tipo Servidor  \
# 0         ABIGAIL DONATA ALVES       1951  Cargo Efetivo/ Estatutário
# 1  ABIGAIL OLIVEIRA DOS SANTOS       9929  Cargo Efetivo/ Estatutário
# 2           ABRAHAO SILVA MAIA       8063  Cargo Efetivo/ Estatutário
# 3        ADAIL SANTOS DE JESUS        510  Cargo Efetivo/ Estatutário
# 4     ADAILSON DE JESUS SANTOS      19310          Cargo Comissionado
#
#                               Cargo Salário Base Salário Vantagens  \
# 0       AGENTE COMUNITÁRIO DE SAÚDE  R$ 1.014,00         R$ 304,20
# 1                 AGENTE DE LIMPEZA    R$ 937,00          R$ 46,85
# 2                  GUARDA MUNICIPAL    R$ 937,00         R$ 281,10
# 3                 AGENTE DE SERVIÇO    R$ 937,00         R$ 234,25
# 4  SUPERVISOR DE ILUMINACAO PUBLICA  R$ 1.050,00           R$ 0,00
#
#   Salário Gratificação
# 0              R$ 0,00
# 1              R$ 0,00
# 2            R$ 234,25
# 3              R$ 0,00
# 4              R$ 0,00

# %%
df_mes['Salário Base'] = df_mes['Salário Base'].apply(lambda x: x.split('R$')[1])
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].apply(lambda x: x.split('R$')[1])
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].apply(lambda x: x.split('R$')[1])

df_mes['Salário Base'] = df_mes['Salário Base'].apply(lambda x: x.split()[0].replace('.', ''))
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].apply(lambda x: x.split()[0].replace('.', ''))
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].apply(lambda x: x.split()[0].replace('.', ''))

df_mes['Salário Base'] = df_mes['Salário Base'].str.replace(',', '.').astype(float)
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].str.replace(',', '.').astype(float)
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].str.replace(',', '.').astype(float)

lista_colunas_sum = ['Salário Base', 'Salário Vantagens', 'Salário Gratificação']
df_mes['Valor Recebido'] = df_mes.loc[:,lista_colunas_sum].sum(axis=1)
df_mes.head()
# Out:
#                           Nome  Matrícula               Tipo Servidor  \
# 0         ABIGAIL DONATA ALVES       1951  Cargo Efetivo/ Estatutário
# 1  ABIGAIL OLIVEIRA DOS SANTOS       9929  Cargo Efetivo/ Estatutário
# 2           ABRAHAO SILVA MAIA       8063  Cargo Efetivo/ Estatutário
# 3        ADAIL SANTOS DE JESUS        510  Cargo Efetivo/ Estatutário
# 4     ADAILSON DE JESUS SANTOS      19310          Cargo Comissionado
#
#                               Cargo  Salário Base  Salário Vantagens  \
# 0       AGENTE COMUNITÁRIO DE SAÚDE        1014.0             304.20
# 1                 AGENTE DE LIMPEZA         937.0              46.85
# 2                  GUARDA MUNICIPAL         937.0             281.10
# 3                 AGENTE DE SERVIÇO         937.0             234.25
# 4  SUPERVISOR DE ILUMINACAO PUBLICA        1050.0               0.00
#
#    Salário Gratificação  Valor Recebido
# 0                  0.00         1318.20
# 1                  0.00          983.85
# 2                234.25         1452.35
# 3                  0.00         1171.25
# 4                  0.00         1050.00

# %%
df_mes.insert(loc=3, 
             column = 'Mês',
             value = 'março')

df_mes.head()
# Out:
#                           Nome  Matrícula               Tipo Servidor    Mês  \
# 0         ABIGAIL DONATA ALVES       1951  Cargo Efetivo/ Estatutário  março
# 1  ABIGAIL OLIVEIRA DOS SANTOS       9929  Cargo Efetivo/ Estatutário  março
# 2           ABRAHAO SILVA MAIA       8063  Cargo Efetivo/ Estatutário  março
# 3        ADAIL SANTOS DE JESUS        510  Cargo Efetivo/ Estatutário  março
# 4     ADAILSON DE JESUS SANTOS      19310          Cargo Comissionado  março
#
#                               Cargo  Salário Base  Salário Vantagens  \
# 0       AGENTE COMUNITÁRIO DE SAÚDE        1014.0             304.20
# 1                 AGENTE DE LIMPEZA         937.0              46.85
# 2                  GUARDA MUNICIPAL         937.0             281.10
# 3                 AGENTE DE SERVIÇO         937.0             234.25
# 4  SUPERVISOR DE ILUMINACAO PUBLICA        1050.0               0.00
#
#    Salário Gratificação  Valor Recebido
# 0                  0.00         1318.20
# 1                  0.00          983.85
# 2                234.25         1452.35
# 3                  0.00         1171.25
# 4                  0.00         1050.00

# %%
df_mes.insert(loc=4, 
             column = 'Ano',
             value = '2017')

df_mes.head()
# Out:
#                           Nome  Matrícula               Tipo Servidor  \
# 0         ABIGAIL DONATA ALVES       1951  Cargo Efetivo/ Estatutário
# 1  ABIGAIL OLIVEIRA DOS SANTOS       9929  Cargo Efetivo/ Estatutário
# 2           ABRAHAO SILVA MAIA       8063  Cargo Efetivo/ Estatutário
# 3        ADAIL SANTOS DE JESUS        510  Cargo Efetivo/ Estatutário
# 4        ADAIL SANTOS DE JESUS        510  Cargo Efetivo/ Estatutário
#
#          Mês   Ano                        Cargo  Salário Base  \
# 0  fevereiro  2017  AGENTE COMUNITÁRIO DE SAÚDE        1014.0
# 1  fevereiro  2017            AGENTE DE LIMPEZA         937.0
# 2  fevereiro  2017             GUARDA MUNICIPAL         937.0
# 3  fevereiro  2017            AGENTE DE SERVIÇO           0.0
# 4  fevereiro  2017            AGENTE DE SERVIÇO         937.0
#
#    Salário Vantagens  Salário Gratificação  Valor Recebido
# 0             304.20                  0.00         1318.20
# 1              46.85                  0.00          983.85
# 2             281.10                234.25         1452.35
# 3               0.00                  0.00            0.00
# 4             234.25                  0.00         1171.25

# %%
df_mes.to_csv('dados-limpos/' + mes + '-2017-limpo.csv', index=False, encoding='utf-8')

# %%
df = pd.read_csv('dados-limpos/' + mes + '-2017-limpo.csv')
df.head()
# Out:
#                           Nome  Matrícula               Tipo Servidor  \
# 0         ABIGAIL DONATA ALVES       1951  Cargo Efetivo/ Estatutário
# 1  ABIGAIL OLIVEIRA DOS SANTOS       9929  Cargo Efetivo/ Estatutário
# 2           ABRAHAO SILVA MAIA       8063  Cargo Efetivo/ Estatutário
# 3        ADAIL SANTOS DE JESUS        510  Cargo Efetivo/ Estatutário
# 4        ADAIL SANTOS DE JESUS        510  Cargo Efetivo/ Estatutário
#
#          Mês   Ano                        Cargo  Salário Base  \
# 0  fevereiro  2017  AGENTE COMUNITÁRIO DE SAÚDE        1014.0
# 1  fevereiro  2017            AGENTE DE LIMPEZA         937.0
# 2  fevereiro  2017             GUARDA MUNICIPAL         937.0
# 3  fevereiro  2017            AGENTE DE SERVIÇO           0.0
# 4  fevereiro  2017            AGENTE DE SERVIÇO         937.0
#
#    Salário Vantagens  Salário Gratificação  Valor Recebido
# 0             304.20                  0.00         1318.20
# 1              46.85                  0.00          983.85
# 2             281.10                234.25         1452.35
# 3               0.00                  0.00            0.00
# 4             234.25                  0.00         1171.25

# %%
import openpyxl
df = pd.read_csv('dados-limpos/' + mes + '-2017-limpo.csv')
df.to_excel('dados-limpos/xlsx/' + mes + '-2017-xlsx.xlsx', index=False, encoding='utf-8')
