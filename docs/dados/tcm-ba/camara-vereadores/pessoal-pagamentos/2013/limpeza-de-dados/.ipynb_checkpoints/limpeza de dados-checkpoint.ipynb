# %%
#Importando biblioteca para trabalhar
import pandas as pd
import numpy as np 

mes = 'mar'
df_mes = pd.read_csv(mes + '.csv', encoding='latin-1', decimal=',')
#df_mes = df_mes.drop(['Unnamed: 7'], axis=1)
df_mes.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0              ABEL MACEDO DE JESUS        157  Cargo Efetivo/ Estatutário
# 1      ADEMILTON SANTANA DE MIRANDA        156             Agente Político
# 2            AFRÂNIO FARIAS BATISTA        142          Cargo Comissionado
# 3    ALFREDO JORGE COSTA DE FREITAS        115          Cargo Comissionado
# 4  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
#
#                  Cargo Salário Base Salário Vantagens Salário Gratificação
# 0  AGENTE DE SEGURANÇA    R$ 678,00         R$ 135,60              R$ 0,00
# 1             VEREADOR  R$ 6.000,00           R$ 0,00              R$ 0,00
# 2  CHEFE DE TRANSPORTE  R$ 1.200,00         R$ 500,00              R$ 0,00
# 3           TESOUREIRO  R$ 1.700,00         R$ 800,00              R$ 0,00
# 4        RECEPCIONISTA    R$ 678,00           R$ 0,00              R$ 0,00

# %%
df_mes['Salário Base'] = df_mes['Salário Base'].apply(lambda x: x.split('R$')[1])
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].apply(lambda x: x.split('R$')[1])
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].apply(lambda x: x.split('R$')[1])

df_mes['Salário Base'] = df_mes['Salário Base'].apply(lambda x: x.split()[0].replace('.', ''))
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].apply(lambda x: x.split()[0].replace('.', ''))
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].apply(lambda x: x.split()[0].replace('.', ''))

df_mes['Salário Base'] = df_mes['Salário Base'].str.replace(',', '.').astype(float)
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].str.replace(',', '.').astype(float)
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].str.replace(',', '.').astype(float)

lista_colunas_sum = ['Salário Base', 'Salário Vantagens', 'Salário Gratificação']
df_mes['Valor Recebido'] = df_mes.loc[:,lista_colunas_sum].sum(axis=1)
df_mes.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0              ABEL MACEDO DE JESUS        157  Cargo Efetivo/ Estatutário
# 1      ADEMILTON SANTANA DE MIRANDA        156             Agente Político
# 2            AFRÂNIO FARIAS BATISTA        142          Cargo Comissionado
# 3    ALFREDO JORGE COSTA DE FREITAS        115          Cargo Comissionado
# 4  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
#
#                  Cargo  Salário Base  Salário Vantagens  Salário Gratificação  \
# 0  AGENTE DE SEGURANÇA         678.0              135.6                   0.0
# 1             VEREADOR        6000.0                0.0                   0.0
# 2  CHEFE DE TRANSPORTE        1200.0              500.0                   0.0
# 3           TESOUREIRO        1700.0              800.0                   0.0
# 4        RECEPCIONISTA         678.0                0.0                   0.0
#
#    Valor Recebido
# 0           813.6
# 1          6000.0
# 2          1700.0
# 3          2500.0
# 4           678.0

# %%
df_mes.insert(loc=3, 
             column = 'Mês',
             value = 'fevereiro')

df_mes.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0              ABEL MACEDO DE JESUS        157  Cargo Efetivo/ Estatutário
# 1      ADEMILTON SANTANA DE MIRANDA        156             Agente Político
# 2            AFRÂNIO FARIAS BATISTA        142          Cargo Comissionado
# 3    ALFREDO JORGE COSTA DE FREITAS        115          Cargo Comissionado
# 4  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
#
#          Mês                Cargo  Salário Base  Salário Vantagens  \
# 0  fevereiro  AGENTE DE SEGURANÇA         678.0              135.6
# 1  fevereiro             VEREADOR        6000.0                0.0
# 2  fevereiro  CHEFE DE TRANSPORTE        1200.0              500.0
# 3  fevereiro           TESOUREIRO        1700.0              800.0
# 4  fevereiro        RECEPCIONISTA         678.0                0.0
#
#    Salário Gratificação  Valor Recebido
# 0                   0.0           813.6
# 1                   0.0          6000.0
# 2                   0.0          1700.0
# 3                   0.0          2500.0
# 4                   0.0           678.0

# %%
df_mes.insert(loc=4, 
             column = 'Ano',
             value = '2013')

df_mes.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0              ABEL MACEDO DE JESUS        157  Cargo Efetivo/ Estatutário
# 1      ADEMILTON SANTANA DE MIRANDA        156             Agente Político
# 2            AFRÂNIO FARIAS BATISTA        142          Cargo Comissionado
# 3    ALFREDO JORGE COSTA DE FREITAS        115          Cargo Comissionado
# 4  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
#
#          Mês   Ano                Cargo  Salário Base  Salário Vantagens  \
# 0  fevereiro  2013  AGENTE DE SEGURANÇA         678.0              135.6
# 1  fevereiro  2013             VEREADOR        6000.0                0.0
# 2  fevereiro  2013  CHEFE DE TRANSPORTE        1200.0              500.0
# 3  fevereiro  2013           TESOUREIRO        1700.0              800.0
# 4  fevereiro  2013        RECEPCIONISTA         678.0                0.0
#
#    Salário Gratificação  Valor Recebido
# 0                   0.0           813.6
# 1                   0.0          6000.0
# 2                   0.0          1700.0
# 3                   0.0          2500.0
# 4                   0.0           678.0

# %%
df_mes.to_csv('dados-limpos/' + mes + '-2013-limpo.csv', index=False, encoding='utf-8')

# %%
df = pd.read_csv('dados-limpos/' + mes + '-2013-limpo.csv')
df.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0              ABEL MACEDO DE JESUS        157  Cargo Efetivo/ Estatutário
# 1      ADEMILTON SANTANA DE MIRANDA        156             Agente Político
# 2            AFRÂNIO FARIAS BATISTA        142          Cargo Comissionado
# 3    ALFREDO JORGE COSTA DE FREITAS        115          Cargo Comissionado
# 4  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
#
#          Mês   Ano                Cargo  Salário Base  Salário Vantagens  \
# 0  fevereiro  2013  AGENTE DE SEGURANÇA         678.0              135.6
# 1  fevereiro  2013             VEREADOR        6000.0                0.0
# 2  fevereiro  2013  CHEFE DE TRANSPORTE        1200.0              500.0
# 3  fevereiro  2013           TESOUREIRO        1700.0              800.0
# 4  fevereiro  2013        RECEPCIONISTA         678.0                0.0
#
#    Salário Gratificação  Valor Recebido
# 0                   0.0           813.6
# 1                   0.0          6000.0
# 2                   0.0          1700.0
# 3                   0.0          2500.0
# 4                   0.0           678.0

# %%
import openpyxl
df = pd.read_csv('dados-limpos/' + mes + '-2013-limpo.csv')
df.to_excel('dados-limpos/xlsx/' + mes + '-2013-xlsx.xlsx', index=False, encoding='utf-8')
