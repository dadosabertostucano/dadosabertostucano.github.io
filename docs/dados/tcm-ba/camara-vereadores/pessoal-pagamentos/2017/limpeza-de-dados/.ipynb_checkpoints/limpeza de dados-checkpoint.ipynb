# %%
#Importando biblioteca para trabalhar
import pandas as pd
import numpy as np 
df_mes = pd.read_csv('fev.csv', encoding='latin-1', decimal=',')
#df_mes = df_mes.drop(['Unnamed: 7'], axis=1)
df_mes.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0              ABEL MACEDO DE JESUS        157  Cargo Efetivo/ Estatutário
# 1      ADEMILTON SANTANA DE MIRANDA        156             Agente Político
# 2  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 3          ARGEMIRA SANTOS DE JESUS         54         Servidor Temporario
# 4       ATEVALDO DE JESUS DAMASCENO        182          Cargo Comissionado
#
#                  Cargo Salário Base Salário Vantagens Salário Gratificação
# 0  AGENTE DE SEGURANÇA    R$ 937,00         R$ 562,20              R$ 0,00
# 1             VEREADOR  R$ 8.000,00           R$ 0,00              R$ 0,00
# 2        RECEPCIONISTA    R$ 937,00          R$ 46,85              R$ 0,00
# 3      Serviços Gerais    R$ 620,40         R$ 612,15              R$ 0,00
# 4  CHEFE DE TRANSPORTE  R$ 1.200,00           R$ 0,00              R$ 0,00

# %%
df_mes['Salário Base'] = df_mes['Salário Base'].apply(lambda x: x.split('R$')[1])
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].apply(lambda x: x.split('R$')[1])
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].apply(lambda x: x.split('R$')[1])

df_mes['Salário Base'] = df_mes['Salário Base'].apply(lambda x: x.split()[0].replace('.', ''))
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].apply(lambda x: x.split()[0].replace('.', ''))
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].apply(lambda x: x.split()[0].replace('.', ''))

df_mes['Salário Base'] = df_mes['Salário Base'].str.replace(',', '.').astype(float)
df_mes['Salário Vantagens'] = df_mes['Salário Vantagens'].str.replace(',', '.').astype(float)
df_mes['Salário Gratificação'] = df_mes['Salário Gratificação'].str.replace(',', '.').astype(float)

lista_colunas_sum = ['Salário Base', 'Salário Vantagens', 'Salário Gratificação']
df_mes['Valor Recebido'] = df_mes.loc[:,lista_colunas_sum].sum(axis=1)
df_mes.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0              ABEL MACEDO DE JESUS        157  Cargo Efetivo/ Estatutário
# 1      ADEMILTON SANTANA DE MIRANDA        156             Agente Político
# 2  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 3          ARGEMIRA SANTOS DE JESUS         54         Servidor Temporario
# 4         BELMIRO FERREIRA DA SILVA        172             Agente Político
#
#                  Cargo  Salário Base  Salário Vantagens  Salário Gratificação  \
# 0  AGENTE DE SEGURANÇA         937.0             562.20                   0.0
# 1             VEREADOR        8000.0               0.00                   0.0
# 2        RECEPCIONISTA         937.0              46.85                   0.0
# 3      Serviços Gerais         620.4             612.15                   0.0
# 4             VEREADOR        8000.0               0.00                   0.0
#
#    Valor Recebido
# 0         1499.20
# 1         8000.00
# 2          983.85
# 3         1232.55
# 4         8000.00

# %%
df_mes.insert(loc=3, 
             column = 'Mês',
             value = 'janeiro')

df_mes.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0              ABEL MACEDO DE JESUS        157  Cargo Efetivo/ Estatutário
# 1      ADEMILTON SANTANA DE MIRANDA        156             Agente Político
# 2  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 3          ARGEMIRA SANTOS DE JESUS         54         Servidor Temporario
# 4         BELMIRO FERREIRA DA SILVA        172             Agente Político
#
#        Mês                Cargo  Salário Base  Salário Vantagens  \
# 0  janeiro  AGENTE DE SEGURANÇA         937.0             562.20
# 1  janeiro             VEREADOR        8000.0               0.00
# 2  janeiro        RECEPCIONISTA         937.0              46.85
# 3  janeiro      Serviços Gerais         620.4             612.15
# 4  janeiro             VEREADOR        8000.0               0.00
#
#    Salário Gratificação  Valor Recebido
# 0                   0.0         1499.20
# 1                   0.0         8000.00
# 2                   0.0          983.85
# 3                   0.0         1232.55
# 4                   0.0         8000.00

# %%
df_mes.insert(loc=4, 
             column = 'Ano',
             value = '2017')

df_mes.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0              ABEL MACEDO DE JESUS        157  Cargo Efetivo/ Estatutário
# 1      ADEMILTON SANTANA DE MIRANDA        156             Agente Político
# 2  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 3          ARGEMIRA SANTOS DE JESUS         54         Servidor Temporario
# 4         BELMIRO FERREIRA DA SILVA        172             Agente Político
#
#        Mês   Ano                Cargo  Salário Base  Salário Vantagens  \
# 0  janeiro  2017  AGENTE DE SEGURANÇA         937.0             562.20
# 1  janeiro  2017             VEREADOR        8000.0               0.00
# 2  janeiro  2017        RECEPCIONISTA         937.0              46.85
# 3  janeiro  2017      Serviços Gerais         620.4             612.15
# 4  janeiro  2017             VEREADOR        8000.0               0.00
#
#    Salário Gratificação  Valor Recebido
# 0                   0.0         1499.20
# 1                   0.0         8000.00
# 2                   0.0          983.85
# 3                   0.0         1232.55
# 4                   0.0         8000.00

# %%
df_mes.to_csv('dados-limpos/jan-2017-limpo.csv', index=False, encoding='utf-8')

# %%
df = pd.read_csv('dados-limpos/jan-2017-limpo.csv')
df.head()
# Out:
#                                Nome  Matrícula               Tipo Servidor  \
# 0              ABEL MACEDO DE JESUS        157  Cargo Efetivo/ Estatutário
# 1      ADEMILTON SANTANA DE MIRANDA        156             Agente Político
# 2  ANE LUISE REIS DE SANTANA MACEDO        111  Cargo Efetivo/ Estatutário
# 3          ARGEMIRA SANTOS DE JESUS         54         Servidor Temporario
# 4         BELMIRO FERREIRA DA SILVA        172             Agente Político
#
#        Mês   Ano                Cargo  Salário Base  Salário Vantagens  \
# 0  janeiro  2017  AGENTE DE SEGURANÇA         937.0             562.20
# 1  janeiro  2017             VEREADOR        8000.0               0.00
# 2  janeiro  2017        RECEPCIONISTA         937.0              46.85
# 3  janeiro  2017      Serviços Gerais         620.4             612.15
# 4  janeiro  2017             VEREADOR        8000.0               0.00
#
#    Salário Gratificação  Valor Recebido
# 0                   0.0         1499.20
# 1                   0.0         8000.00
# 2                   0.0          983.85
# 3                   0.0         1232.55
# 4                   0.0         8000.00

# %%
import openpyxl
df = pd.read_csv('dados-limpos/jan-2017-limpo.csv')
df.to_excel('dados-limpos/xlsx/jan-2017-xlsx.xlsx', index=False, encoding='utf-8')
